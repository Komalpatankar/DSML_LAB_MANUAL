# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# import the data
data= pd.read_csv("/content/insurance.csv")
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
data.var()
# Out:
# <ipython-input-4-6bf595b3cfe5>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.var()
# age         1.974014e+02
# bmi         3.718788e+01
# children    1.453213e+00
# charges     1.466524e+08
# dtype: float64

# %%
a=data["age"]
plt.hist(a,edgecolor="black")
plt.xlabel("age")


plt.title("age")
plt.legend()
plt.show
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
b=data["bmi"]
plt.hist(b,color="pink",edgecolor="black")
plt.title("bmi")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
c=data["children"]
plt.hist(c,alpha=0.5,color="green",edgecolor="black")
plt.title("children")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
d=data["charges"]
plt.hist(d,color="yellow",edgecolor="black")
plt.title("charges")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
